# %%
import os
import json
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

import joblib


# ============================================================
# 1. PATH SETUP
# ============================================================

input_file = r"C:\Users\NXTWAVE\Downloads\Global Energy Recovery\Food_Delivery_Time_Prediction.csv"
output_dir = r"C:\Users\NXTWAVE\Downloads\Global Energy Recovery"

os.makedirs(output_dir, exist_ok=True)

print("Output Directory:")
print(output_dir)


# ============================================================
# 2. LOAD DATASET
# ============================================================

df = pd.read_csv(input_file)

print("\nDataset Loaded Successfully")
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nFirst 5 Rows:")
display(df.head())


# ============================================================
# 3. BASIC CLEANING
# ============================================================

df.columns = df.columns.str.strip()
df.drop_duplicates(inplace=True)

print("\nShape After Removing Duplicates:", df.shape)

print("\nMissing Values Before Cleaning:")
print(df.isnull().sum())


# ============================================================
# 4. HANDLE OUTLIERS
# ============================================================

def cap_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    data[column] = np.where(data[column] < lower_limit, lower_limit, data[column])
    data[column] = np.where(data[column] > upper_limit, upper_limit, data[column])

    return data


numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()

for col in numeric_cols:
    df = cap_outliers_iqr(df, col)

print("\nOutlier Treatment Completed")


# ============================================================
# 5. HANDLE MISSING VALUES
# ============================================================

numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()

num_imputer = SimpleImputer(strategy="median")
cat_imputer = SimpleImputer(strategy="most_frequent")

if len(numeric_cols) > 0:
    df[numeric_cols] = num_imputer.fit_transform(df[numeric_cols])

if len(categorical_cols) > 0:
    df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])

print("\nMissing Values After Cleaning:")
print(df.isnull().sum())


# ============================================================
# 6. FEATURE ENGINEERING
# ============================================================

# ------------------------------------------------------------
# Energy Consumption Per Capita
# ------------------------------------------------------------

energy_cols = [
    col for col in df.columns
    if "energy" in col.lower() or "consumption" in col.lower()
]

population_cols = [
    col for col in df.columns
    if "population" in col.lower() or "capita" in col.lower()
]

if energy_cols and population_cols:
    energy_col = energy_cols[0]
    population_col = population_cols[0]

    df["Energy_Consumption_Per_Capita"] = (
        df[energy_col] / (df[population_col] + 1)
    )
else:
    numeric_cols_temp = df.select_dtypes(include=["int64", "float64"]).columns.tolist()

    if len(numeric_cols_temp) >= 2:
        df["Energy_Consumption_Per_Capita"] = (
            df[numeric_cols_temp[0]] / (df[numeric_cols_temp[1]] + 1)
        )
    else:
        df["Energy_Consumption_Per_Capita"] = 0


# ------------------------------------------------------------
# Yearly Pollution Trend
# ------------------------------------------------------------

year_cols = [col for col in df.columns if "year" in col.lower()]
pollution_cols = [
    col for col in df.columns
    if "pollution" in col.lower()
    or "co2" in col.lower()
    or "emission" in col.lower()
    or "waste" in col.lower()
]

if year_cols and pollution_cols:
    year_col = year_cols[0]
    pollution_col = pollution_cols[0]

    df = df.sort_values(by=year_col)
    df["Yearly_Pollution_Trend"] = df[pollution_col].diff().fillna(0)
else:
    df["Yearly_Pollution_Trend"] = 0


# ------------------------------------------------------------
# Overall Pollution Index
# ------------------------------------------------------------

pollution_index_cols = [
    col for col in df.columns
    if "air" in col.lower()
    or "water" in col.lower()
    or "soil" in col.lower()
    or "pollution" in col.lower()
    or "co2" in col.lower()
    or "emission" in col.lower()
    or "waste" in col.lower()
]

pollution_index_cols = [
    col for col in pollution_index_cols
    if df[col].dtype != "object"
]

if len(pollution_index_cols) > 0:
    df["Overall_Pollution_Index"] = df[pollution_index_cols].mean(axis=1)
else:
    numeric_cols_temp = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
    df["Overall_Pollution_Index"] = df[numeric_cols_temp].mean(axis=1)


print("\nFeature Engineering Completed")


# ============================================================
# 7. CREATE TARGET VARIABLE
# ============================================================

low_threshold = df["Overall_Pollution_Index"].quantile(0.33)
high_threshold = df["Overall_Pollution_Index"].quantile(0.66)

def pollution_category(value):
    if value <= low_threshold:
        return "Low"
    elif value <= high_threshold:
        return "Medium"
    else:
        return "High"

df["Pollution_Severity"] = df["Overall_Pollution_Index"].apply(pollution_category)

print("\nPollution Severity Distribution:")
print(df["Pollution_Severity"].value_counts())


# ============================================================
# 8. ENCODE CATEGORICAL FEATURES
# ============================================================

label_encoders = {}

categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()

if "Pollution_Severity" in categorical_cols:
    categorical_cols.remove("Pollution_Severity")

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le

target_encoder = LabelEncoder()
df["Pollution_Severity_Encoded"] = target_encoder.fit_transform(df["Pollution_Severity"])

print("\nTarget Classes:")
print(dict(zip(target_encoder.classes_, target_encoder.transform(target_encoder.classes_))))


# ============================================================
# 9. FEATURE SELECTION
# ============================================================

drop_cols = [
    "Pollution_Severity",
    "Pollution_Severity_Encoded"
]

X = df.drop(columns=drop_cols)
y = df["Pollution_Severity_Encoded"]

print("\nFinal Feature Columns:")
print(X.columns.tolist())

print("\nFeature Shape:", X.shape)
print("Target Shape:", y.shape)


# ============================================================
# 10. FEATURE SCALING
# ============================================================

standard_scaler = StandardScaler()
X_scaled = standard_scaler.fit_transform(X)

# MultinomialNB requires non-negative values
minmax_scaler = MinMaxScaler()
X_mnb = minmax_scaler.fit_transform(X)

preprocessed_df = pd.DataFrame(X_scaled, columns=X.columns)
preprocessed_df["Pollution_Severity"] = df["Pollution_Severity"].values

preprocessed_path = os.path.join(output_dir, "preprocessed_global_pollution_data.csv")
preprocessed_df.to_csv(preprocessed_path, index=False)

print("\nPreprocessed Data Saved:")
print(preprocessed_path)


# ============================================================
# 11. TRAIN TEST SPLIT
# ============================================================

X_train_scaled, X_test_scaled, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

X_train_mnb, X_test_mnb, _, _ = train_test_split(
    X_mnb,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print("\nTraining Shape:", X_train_scaled.shape)
print("Testing Shape:", X_test_scaled.shape)


# ============================================================
# 12. MODEL EVALUATION FUNCTION
# ============================================================

results = []

def evaluate_model(model_name, model, X_test, y_test):
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average="weighted")
    recall = recall_score(y_test, y_pred, average="weighted")
    f1 = f1_score(y_test, y_pred, average="weighted")

    results.append({
        "Model": model_name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1_Score": f1
    })

    print("\n" + "=" * 60)
    print(model_name)
    print("=" * 60)
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

    print("\nClassification Report:")
    print(
        classification_report(
            y_test,
            y_pred,
            target_names=target_encoder.classes_
        )
    )

    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(7, 5))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=target_encoder.classes_,
        yticklabels=target_encoder.classes_
    )
    plt.title(f"{model_name} - Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()

    cm_path = os.path.join(
        output_dir,
        f"{model_name.replace(' ', '_')}_confusion_matrix.png"
    )

    plt.savefig(cm_path, dpi=300)
    plt.show()

    return y_pred


# ============================================================
# 13. MULTINOMIAL NAIVE BAYES
# ============================================================

mnb_model = MultinomialNB()
mnb_model.fit(X_train_mnb, y_train)

mnb_pred = evaluate_model(
    "Multinomial Naive Bayes",
    mnb_model,
    X_test_mnb,
    y_test
)


# ============================================================
# 14. KNN CLASSIFIER WITH HYPERPARAMETER TUNING
# ============================================================

knn_params = {
    "n_neighbors": list(range(3, 21, 2)),
    "weights": ["uniform", "distance"],
    "metric": ["euclidean", "manhattan"]
}

knn_grid = GridSearchCV(
    KNeighborsClassifier(),
    knn_params,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)

knn_grid.fit(X_train_scaled, y_train)

best_knn = knn_grid.best_estimator_

print("\nBest KNN Parameters:")
print(knn_grid.best_params_)

knn_pred = evaluate_model(
    "KNN",
    best_knn,
    X_test_scaled,
    y_test
)


# ============================================================
# 15. DECISION TREE WITH HYPERPARAMETER TUNING
# ============================================================

dt_params = {
    "max_depth": [2, 3, 4, 5, 6, 8, 10, None],
    "min_samples_split": [2, 5, 10, 15],
    "min_samples_leaf": [1, 2, 4, 6],
    "criterion": ["gini", "entropy"]
}

dt_grid = GridSearchCV(
    DecisionTreeClassifier(random_state=42),
    dt_params,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)

dt_grid.fit(X_train_scaled, y_train)

best_dt = dt_grid.best_estimator_

print("\nBest Decision Tree Parameters:")
print(dt_grid.best_params_)

dt_pred = evaluate_model(
    "Decision Tree",
    best_dt,
    X_test_scaled,
    y_test
)


# ============================================================
# 16. MODEL COMPARISON
# ============================================================

results_df = pd.DataFrame(results)

results_path = os.path.join(output_dir, "model_comparison_results.csv")
results_df.to_csv(results_path, index=False)

print("\nModel Comparison Results:")
display(results_df)

plt.figure(figsize=(10, 6))

x = np.arange(len(results_df["Model"]))
width = 0.2

plt.bar(x - width, results_df["Accuracy"], width, label="Accuracy")
plt.bar(x, results_df["Precision"], width, label="Precision")
plt.bar(x + width, results_df["Recall"], width, label="Recall")
plt.bar(x + 2 * width, results_df["F1_Score"], width, label="F1 Score")

plt.xticks(x, results_df["Model"], rotation=15)
plt.ylabel("Score")
plt.title("Model Performance Comparison")
plt.legend()
plt.tight_layout()

comparison_graph_path = os.path.join(output_dir, "model_performance_comparison.png")
plt.savefig(comparison_graph_path, dpi=300)
plt.show()


# ============================================================
# 17. FEATURE IMPORTANCE
# ============================================================

feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": best_dt.feature_importances_
}).sort_values(by="Importance", ascending=False)

feature_importance_path = os.path.join(
    output_dir,
    "decision_tree_feature_importance.csv"
)

feature_importance.to_csv(feature_importance_path, index=False)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=feature_importance.head(10),
    x="Importance",
    y="Feature"
)
plt.title("Top 10 Important Features - Decision Tree")
plt.tight_layout()

feature_importance_graph_path = os.path.join(
    output_dir,
    "decision_tree_feature_importance.png"
)

plt.savefig(feature_importance_graph_path, dpi=300)
plt.show()


# ============================================================
# 18. DECISION TREE VISUALIZATION
# ============================================================

plt.figure(figsize=(22, 12))

plot_tree(
    best_dt,
    feature_names=X.columns,
    class_names=target_encoder.classes_,
    filled=True,
    rounded=True,
    fontsize=8
)

tree_path = os.path.join(output_dir, "decision_tree_visualization.png")
plt.savefig(tree_path, dpi=300, bbox_inches="tight")
plt.show()


# ============================================================
# 19. SAVE PREDICTIONS
# ============================================================

prediction_df = pd.DataFrame({
    "Actual_Encoded": y_test.values,
    "Actual_Label": target_encoder.inverse_transform(y_test.values),
    "Multinomial_Naive_Bayes_Prediction": target_encoder.inverse_transform(mnb_pred),
    "KNN_Prediction": target_encoder.inverse_transform(knn_pred),
    "Decision_Tree_Prediction": target_encoder.inverse_transform(dt_pred)
})

prediction_path = os.path.join(output_dir, "pollution_severity_predictions.csv")
prediction_df.to_csv(prediction_path, index=False)

print("\nPrediction File Saved:")
print(prediction_path)


# ============================================================
# 20. SAVE MODELS
# ============================================================

joblib.dump(mnb_model, os.path.join(output_dir, "multinomial_naive_bayes_model.pkl"))
joblib.dump(best_knn, os.path.join(output_dir, "knn_model.pkl"))
joblib.dump(best_dt, os.path.join(output_dir, "decision_tree_model.pkl"))
joblib.dump(standard_scaler, os.path.join(output_dir, "standard_scaler.pkl"))
joblib.dump(minmax_scaler, os.path.join(output_dir, "minmax_scaler.pkl"))
joblib.dump(label_encoders, os.path.join(output_dir, "label_encoders.pkl"))
joblib.dump(target_encoder, os.path.join(output_dir, "target_encoder.pkl"))

print("\nModels Saved Successfully")


# ============================================================
# 21. FINAL REPORT
# ============================================================

best_model_row = results_df.sort_values(by="F1_Score", ascending=False).iloc[0]
best_model_name = best_model_row["Model"]

report = f"""
# Global Pollution Severity Classification Report

## Objective

The goal of this project is to classify countries into different pollution severity categories:

- Low
- Medium
- High

The classification is based on pollution levels, energy consumption, industrial waste, CO2 emissions, and other environmental indicators.

## Dataset

Input Dataset:

{input_file}

Total Records:

{df.shape[0]}

Total Features Used:

{X.shape[1]}

## Target Variable

The target variable `Pollution_Severity` was created using the `Overall_Pollution_Index`.

Thresholds used:

- Low Pollution Threshold: {low_threshold}
- High Pollution Threshold: {high_threshold}

## Models Used

Three classification algorithms were used:

1. Multinomial Naive Bayes
2. K-Nearest Neighbors
3. Decision Tree Classifier

## Model Performance

{results_df.to_string(index=False)}

## Best Model

The best model based on weighted F1-score is:

{best_model_name}

## Key Insights

### Pollution Classification

Countries or records with higher pollution index values were classified as High severity, while lower values were classified as Low severity.

### Energy Consumption Per Capita

Energy consumption per capita was engineered to understand how energy usage relates to pollution severity.

### Yearly Pollution Trend

Yearly pollution trend was created to observe whether pollution indicators are increasing or decreasing over time.

### Decision Tree Insights

The Decision Tree model provides feature importance, helping identify which environmental factors contribute most to pollution severity.

## Policy Recommendations

1. Countries with High pollution severity should focus on stricter emission control policies.
2. Industrial waste management systems should be improved.
3. Renewable energy adoption should be encouraged.
4. Energy recovery systems should be promoted to reduce waste and improve sustainability.
5. Countries with rising yearly pollution trends should be monitored continuously.
6. Public transportation and clean fuel policies can help reduce CO2 emissions.
7. Pollution monitoring dashboards should be implemented for real-time environmental tracking.

## Generated Files

- preprocessed_global_pollution_data.csv
- model_comparison_results.csv
- pollution_severity_predictions.csv
- decision_tree_feature_importance.csv
- model_performance_comparison.png
- decision_tree_feature_importance.png
- decision_tree_visualization.png
- Multinomial_Naive_Bayes_confusion_matrix.png
- KNN_confusion_matrix.png
- Decision_Tree_confusion_matrix.png
- multinomial_naive_bayes_model.pkl
- knn_model.pkl
- decision_tree_model.pkl
- standard_scaler.pkl
- minmax_scaler.pkl
- label_encoders.pkl
- target_encoder.pkl
- result_summary.json

## Final Recommendation

The recommended model is {best_model_name}, as it achieved the best weighted F1-score.

If interpretability is important, the Decision Tree classifier is preferred because it shows which features are most responsible for pollution severity classification.
"""

report_path = os.path.join(output_dir, "final_pollution_classification_report.md")

with open(report_path, "w", encoding="utf-8") as f:
    f.write(report)

print("\nFinal Report Saved:")
print(report_path)


# ============================================================
# 22. JSON SUMMARY
# ============================================================

summary = {
    "dataset_path": input_file,
    "output_directory": output_dir,
    "total_records": int(df.shape[0]),
    "total_features": int(X.shape[1]),
    "low_threshold": float(low_threshold),
    "high_threshold": float(high_threshold),
    "best_model": best_model_name,
    "best_model_f1_score": float(best_model_row["F1_Score"]),
    "knn_best_params": knn_grid.best_params_,
    "decision_tree_best_params": dt_grid.best_params_,
    "model_results": results_df.to_dict(orient="records")
}

json_path = os.path.join(output_dir, "result_summary.json")

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(summary, f, indent=4)

print("\nJSON Summary Saved:")
print(json_path)


# ============================================================
# 23. FINAL OUTPUT
# ============================================================

print("\nProject Completed Successfully!")
print("\nAll files saved in:")
print(output_dir)
# Out:
# Output Directory:
# C:\Users\NXTWAVE\Downloads\Global Energy Recovery
#
# Dataset Loaded Successfully
# Shape: (200, 15)
#
# Columns:
# ['Order_ID', 'Customer_Location', 'Restaurant_Location', 'Distance', 'Weather_Conditions', 'Traffic_Conditions', 'Delivery_Person_Experience', 'Order_Priority', 'Order_Time', 'Vehicle_Type', 'Restaurant_Rating', 'Customer_Rating', 'Delivery_Time', 'Order_Cost', 'Tip_Amount']
#
# First 5 Rows:
#   Order_ID       Customer_Location     Restaurant_Location  Distance  \
# 0  ORD0001  (17.030479, 79.743077)  (12.358515, 85.100083)      1.57
# 1  ORD0002  (15.398319, 86.639122)  (14.174874, 77.025606)     21.32
# 2  ORD0003  (15.687342, 83.888808)  (19.594748, 82.048482)      6.95
# 3  ORD0004  (20.415599, 78.046984)  (16.915906, 78.278698)     13.79
# 4  ORD0005  (14.786904, 78.706532)  (15.206038, 86.203182)      6.72
#
#   Weather_Conditions Traffic_Conditions  Delivery_Person_Experience  \
# 0              Rainy             Medium                           4
# 1             Cloudy             Medium                           8
# 2              Snowy             Medium                           9
# 3             Cloudy                Low                           2
# 4              Rainy               High                           6
#
#   Order_Priority Order_Time Vehicle_Type  Restaurant_Rating  Customer_Rating  \
# 0         Medium  Afternoon          Car                4.1              3.0
# 1            Low      Night          Car                4.5              4.2
# 2           High      Night         Bike                3.3              3.4
# 3         Medium    Evening         Bike                3.2              3.7
# 4            Low      Night         Bike                3.5              2.8
#
#    Delivery_Time  Order_Cost  Tip_Amount
# 0          26.22     1321.10       81.54
# 1          62.61      152.21       29.02
# 2          48.43     1644.38       64.17
# 3         111.63      541.25       79.23
# 4          32.38      619.81        2.34
# Shape After Removing Duplicates: (200, 15)
#
# Missing Values Before Cleaning:
# Order_ID                      0
# Customer_Location             0
# Restaurant_Location           0
# Distance                      0
# Weather_Conditions            0
# Traffic_Conditions            0
# Delivery_Person_Experience    0
# Order_Priority                0
# Order_Time                    0
# Vehicle_Type                  0
# Restaurant_Rating             0
# Customer_Rating               0
# Delivery_Time                 0
# Order_Cost                    0
# Tip_Amount                    0
# dtype: int64
#
# Outlier Treatment Completed
#
# Missing Values After Cleaning:
# Order_ID                      0
# Customer_Location             0
# Restaurant_Location           0
# Distance                      0
# Weather_Conditions            0
# Traffic_Conditions            0
# Delivery_Person_Experience    0
# Order_Priority                0
# Order_Time                    0
# Vehicle_Type                  0
# Restaurant_Rating             0
# Customer_Rating               0
# Delivery_Time                 0
# Order_Cost                    0
# Tip_Amount                    0
# dtype: int64
#
# Feature Engineering Completed
#
# Pollution Severity Distribution:
# Pollution_Severity
# Low    200
# Name: count, dtype: int64
#
# Target Classes:
# {'Low': np.int64(0)}
#
# Final Feature Columns:
# ['Order_ID', 'Customer_Location', 'Restaurant_Location', 'Distance', 'Weather_Conditions', 'Traffic_Conditions', 'Delivery_Person_Experience', 'Order_Priority', 'Order_Time', 'Vehicle_Type', 'Restaurant_Rating', 'Customer_Rating', 'Delivery_Time', 'Order_Cost', 'Tip_Amount', 'Energy_Consumption_Per_Capita', 'Yearly_Pollution_Trend', 'Overall_Pollution_Index']
#
# Feature Shape: (200, 18)
# Target Shape: (200,)
#
# Preprocessed Data Saved:
# C:\Users\NXTWAVE\Downloads\Global Energy Recovery\preprocessed_global_pollution_data.csv
#
# Training Shape: (160, 18)
# Testing Shape: (40, 18)
#
# ============================================================
# Multinomial Naive Bayes
# ============================================================
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Low       1.00      1.00      1.00        40
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
# Best KNN Parameters:
# {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
#
# ============================================================
# KNN
# ============================================================
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Low       1.00      1.00      1.00        40
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
# Best Decision Tree Parameters:
# {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# ============================================================
# Decision Tree
# ============================================================
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Low       1.00      1.00      1.00        40
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
# Model Comparison Results:
#                      Model  Accuracy  Precision  Recall  F1_Score
# 0  Multinomial Naive Bayes       1.0        1.0     1.0       1.0
# 1                      KNN       1.0        1.0     1.0       1.0
# 2            Decision Tree       1.0        1.0     1.0       1.0
# Prediction File Saved:
# C:\Users\NXTWAVE\Downloads\Global Energy Recovery\pollution_severity_predictions.csv
#
# Models Saved Successfully
#
# Final Report Saved:
# C:\Users\NXTWAVE\Downloads\Global Energy Recovery\final_pollution_classification_report.md
#
# JSON Summary Saved:
# C:\Users\NXTWAVE\Downloads\Global Energy Recovery\result_summary.json
#
# Project Completed Successfully!
#
# All files saved in:
# C:\Users\NXTWAVE\Downloads\Global Energy Recovery
